# %% [markdown]
# Importing required libraries

# %%
import pandas as pd
import numpy as np
import sqlite3 as sql

# %%
# create connection to the databse file
database = "crimewomen.db"
connection = sql.connect(database)

# %% [markdown]
# 3.1	Insert records from 42_District_wise_crimes_committed_against_women_2001_2012.csv into a table

# %%
query = 'SELECT * FROM crimewomen'

# %%
df = pd.read_sql_query(query,connection)
df
# Out:
#           STATEUT   DISTRICT  Year  Rape  Kidnapping_and_Abduction  \
# 0  ANDHRA PRADESH   ADILABAD  2001    50                        30
# 1  ANDHRA PRADESH   ADILABAD  2001    50                        30
# 2  ANDHRA PRADESH  ANANTAPUR  2001    23                        30
# 3  ANDHRA PRADESH   CHITTOOR  2001    27                        34
# 4  ANDHRA PRADESH   CUDDAPAH  2001    20                        20
#
#    Dowry_Deaths  Assault_on_women_with_intent_to_outrage_her_modesty  \
# 0            16                                                149
# 1            16                                                149
# 2             7                                                118
# 3            14                                                112
# 4            17                                                126
#
#    Insult_to_modesty_of_Women  Cruelty_by_Husband_or_his_Relatives  \
# 0                          34                                  175
# ...

# %% [markdown]
# The records from 3.1 42_District_wise_crimes_committed_against_women_2001_2012.csv inserted into crimewomen table

# %% [markdown]
# 3.2	Write SQL query to find the highest number of rapes & Kidnappings that happened in which state, District, and year

# %% [markdown]
# While inserting/viewing records there wheresome records where discrtict is TOTAL per year and soem for DELHHI UT total for all years these records will not help to get exact information so have defined them in not eqal to condition while fetching records

# %%
query1 = 'SELECT MAX(Rape),stateut,district,year FROM crimewomen WHERE DISTRICT <> "TOTAL" AND DISTRICT <> "DELHI UT TOTAL" ORDER BY Rape'

# %%
df1=pd.read_sql_query(query1,connection)

# %%
df1
# Out:
#    MAX(Rape)      STATEUT     DISTRICT  Year
# 0        568  WEST BENGAL  MURSHIDABAD  2009

# %%
query2= 'SELECT MAX(Kidnapping_and_Abduction),stateut,district,year FROM crimewomen WHERE DISTRICT <> "TOTAL" AND DISTRICT <> "DELHI UT TOTAL" ORDER BY Kidnapping_and_Abduction'

# %%
df2=pd.read_sql_query(query2,connection)

# %%
df2
# Out:
#    MAX(Kidnapping_and_Abduction)      STATEUT     DISTRICT  Year
# 0                            492  WEST BENGAL  MURSHIDABAD  2011

# %% [markdown]
# 3.3	Write SQL query to find All the lowest number of rapes & Kidnappings that happened in which state, District, and year

# %%
query3='SELECT MIN(Rape),stateut,district,year FROM crimewomen WHERE DISTRICT <> "TOTAL" AND DISTRICT <> "DELHI UT TOTAL" ORDER BY Rape'

# %%
df3=pd.read_sql_query(query3,connection)

# %%
df3
# Out:
#    MIN(Rape)         STATEUT       DISTRICT  Year
# 0          0  ANDHRA PRADESH  GUNTAKAL RLY.  2001

# %%
query4='SELECT MIN(Kidnapping_and_Abduction),stateut,district,year FROM crimewomen WHERE DISTRICT <> "TOTAL" AND DISTRICT <> "DELHI UT TOTAL" '

# %%
df4=pd.read_sql_query(query4,connection)
df4
# Out:
#    MIN(Kidnapping_and_Abduction)         STATEUT       DISTRICT  Year
# 0                              0  ANDHRA PRADESH  GUNTAKAL RLY.  2001

# %% [markdown]
# 3.4	Insert records from 02_District_wise_crimes_committed_against_ST_2001_2012.csv into a new table

# %%
q1 = 'SELECT * FROM crimest'

# %%
df5 = pd.read_sql_query(q1,connection)
df5
# Out:
#              STATEUT       DISTRICT  Year  Murder  Rape  Kidnapping_Abduction  \
# 0     ANDHRA PRADESH       ADILABAD  2001       0     1                     2
# 1     ANDHRA PRADESH      ANANTAPUR  2001       0     0                     0
# 2     ANDHRA PRADESH       CHITTOOR  2001       0     0                     0
# 3     ANDHRA PRADESH       CUDDAPAH  2001       0     0                     0
# 4     ANDHRA PRADESH  EAST GODAVARI  2001       0     0                     0
# ...              ...            ...   ...     ...   ...                   ...
# 9013     LAKSHADWEEP    LAKSHADWEEP  2012       0     0                     0
# 9014     LAKSHADWEEP          TOTAL  2012       0     0                     0
# 9015      PUDUCHERRY       KARAIKAL  2012       0     0                     0
# 9016      PUDUCHERRY     PUDUCHERRY  2012       0     0                     0
# 9017      PUDUCHERRY          TOTAL  2012       0     0                     0
#
# ...

# %% [markdown]
# 3.5	Write SQL query to find the highest number of dacoity/robbery in which district

# %%
q2='SELECT MAX(dacoity),MAX(robbery),district FROM crimest WHERE DISTRICT <> "TOTAL" AND DISTRICT <> "DELHI UT TOTAL"'

# %%
df4=pd.read_sql_query(q2,connection)
df4
# Out:
#    MAX(dacoity)  MAX(robbery) DISTRICT
# 0            29            32    DAHOD

# %% [markdown]
# 3.6	Write SQL query to find in which districts(All) the lowest number of murders happened

# %%
q2='SELECT Min(MURDER),district FROM crimest WHERE DISTRICT <> "TOTAL" AND DISTRICT <> "DELHI UT TOTAL"ORDER BY district'
df4=pd.read_sql_query(q2,connection)
df4
# Out:
#    Min(MURDER)  DISTRICT
# 0            0  ADILABAD

# %% [markdown]
# 3.7	Write SQL query to find the number of murders in ascending order in district and yearwise.

# %%
q2='SELECT MURDER,district,year FROM crimest WHERE DISTRICT <> "TOTAL" AND DISTRICT <> "DELHI UT TOTAL"ORDER BY year'
df4=pd.read_sql_query(q2,connection)
df4
# Out:
#       Murder       DISTRICT  Year
# 0          0       ADILABAD  2001
# 1          0      ANANTAPUR  2001
# 2          0       CHITTOOR  2001
# 3          0       CUDDAPAH  2001
# 4          0  EAST GODAVARI  2001
# ...      ...            ...   ...
# 8592       0            STF  2012
# 8593       0           WEST  2012
# 8594       0    LAKSHADWEEP  2012
# 8595       0       KARAIKAL  2012
# 8596       0     PUDUCHERRY  2012
#
# [8597 rows x 3 columns]

# %% [markdown]
# 3.8.1 Insert records of STATE/UT, DISTRICT, YEAR, MURDER, ATTEMPT TO MURDER, and RAPE columns only from 01_District_wise_crimes_committed_IPC_2001_2012.csv into a new table

# %%
qu1= 'SELECT * FROM crimeipc'

# %%
df6 = pd.read_sql_query(qu1,connection)
df6
# Out:
#              STATEUT       DISTRICT  YEAR  MURDER  ATTEMPT_TO_MURDER  \
# 0     ANDHRA PRADESH       ADILABAD  2001     101                 60
# 1     ANDHRA PRADESH      ANANTAPUR  2001     151                125
# 2     ANDHRA PRADESH       CHITTOOR  2001     101                 57
# 3     ANDHRA PRADESH       CUDDAPAH  2001      80                 53
# 4     ANDHRA PRADESH  EAST GODAVARI  2001      82                 67
# ...              ...            ...   ...     ...                ...
# 9012     LAKSHADWEEP    LAKSHADWEEP  2012       0                  0
# 9013     LAKSHADWEEP          TOTAL  2012       0                  0
# 9014      PUDUCHERRY       KARAIKAL  2012       5                  6
# 9015      PUDUCHERRY     PUDUCHERRY  2012      24                 21
# 9016      PUDUCHERRY          TOTAL  2012      29                 27
#
#       CULPABLE_HOMICIDE_NOT_AMOUNTING_TO_MURDER  RAPE  CUSTODIAL_RAPE  \
# ...

# %% [markdown]
# 3.8.2	Write SQL query to find which District in each state/ut has the highest number of murders yearwise. Your output should show STATE/UT, YEAR, DISTRICT, and MURDERS.

# %%
q2='SELECT STATEUT,DISTRICT,YEAR,MURDER FROM crimeipc WHERE DISTRICT <> "TOTAL" AND DISTRICT <> "DELHI UT TOTAL"ORDER BY MURDER DESC'
df4=pd.read_sql_query(q2,connection)
df4
# Out:
#           STATEUT     DISTRICT  YEAR  MURDER
# 0           BIHAR        PATNA  2004     542
# 1           BIHAR        PATNA  2003     484
# 2           BIHAR        PATNA  2002     472
# 3           BIHAR        PATNA  2005     436
# 4           BIHAR        PATNA  2001     434
# ...           ...          ...   ...     ...
# 8592  DAMAN & DIU          DIU  2012       0
# 8593     DELHI UT          CAW  2012       0
# 8594     DELHI UT          EOW  2012       0
# 8595     DELHI UT          STF  2012       0
# 8596  LAKSHADWEEP  LAKSHADWEEP  2012       0
#
# [8597 rows x 4 columns]

# %% [markdown]
# 3.8.3	Store the above data (the result of 3.2) in DataFrame and analyze districts that appear 3 or more than 3 years and print the corresponding state/ut, district, murders, and year in descending order.

# %%
df4
# Out:
#           STATEUT     DISTRICT  YEAR  MURDER
# 0           BIHAR        PATNA  2004     542
# 1           BIHAR        PATNA  2003     484
# 2           BIHAR        PATNA  2002     472
# 3           BIHAR        PATNA  2005     436
# 4           BIHAR        PATNA  2001     434
# ...           ...          ...   ...     ...
# 8592  DAMAN & DIU          DIU  2012       0
# 8593     DELHI UT          CAW  2012       0
# 8594     DELHI UT          EOW  2012       0
# 8595     DELHI UT          STF  2012       0
# 8596  LAKSHADWEEP  LAKSHADWEEP  2012       0
#
# [8597 rows x 4 columns]

# %% [markdown]
# 3.8.4	Use appropriate graphs to show your data (the result of 3.8.3)
