# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
# %matplotlib inline

from sklearn.linear_model import LinearRegression

# %% [markdown]
# importing data

# %%
df = pd.read_csv(r"C:\Users\Dell\Desktop\fliprobonotes\StateandUT_Wise_population.csv")

# %%
df
# Out:
#     SR.No.                      State    Population  Male Literacy Rate  \
# 0        1  Andaman & Nicobar Islands      3,80,581               90.11
# 1        2             Andhra Pradesh   8,45,80,777               73.40
# 2        3          Arunachal Pradesh     13,83,727               73.69
# 3        4                      Assam   3,12,05,576               90.10
# 4        5                      Bihar  10,40,99,452               79.70
# 5        6                 Chandigarh     10,55,450               85.40
# 6        7               Chhattisgarh   2,55,45,198               90.54
# 7        8     Dadra and Nagar Haveli      3,43,709               86.46
# 8        9              Daman and Diu      2,43,247               91.48
# 9       10                      Delhi   1,67,87,941               93.70
# 10      11                        Goa     14,58,545               92.81
# 11      12                    Gujarat   6,04,39,692               89.50
# ...

# %% [markdown]
# From the above we can see that there are total 36 records of state and union teritory of India
